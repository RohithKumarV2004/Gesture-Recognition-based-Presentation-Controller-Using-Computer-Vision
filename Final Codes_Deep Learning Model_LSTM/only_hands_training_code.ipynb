# %%
pip install tensorflow opencv-python mediapipe scikit-learn matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (2.18.0)
# Requirement already satisfied: opencv-python in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (4.11.0.86)
# Requirement already satisfied: mediapipe in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (0.10.20)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: jax in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: jaxlib in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: CFFI>=1.0 in c:\programdata\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: rich in c:\programdata\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\fyp team 11\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# FUNCTIONS FOR DETECTING OR EXTRACTING HANDS

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
def extract_keypoints(results):
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21 * 3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21 * 3)
    return np.concatenate([lh, rh])  # Output size will be (126,)

# %%
def extract_hand(frame, model):
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    frame.flags.writeable = False                  
    results = model.process(frame)                 
    frame.flags.writeable = True                   
    frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)  # Convert RGB back to BGR

    # Check if any hand is detected
    if results.right_hand_landmarks:
        hand_landmarks = results.right_hand_landmarks.landmark
    elif results.left_hand_landmarks:
        hand_landmarks = results.left_hand_landmarks.landmark
    else:
        return None, results

    # Get bounding box
    x_min, y_min = float('inf'), float('inf')
    x_max, y_max = 0, 0

    h, w, _ = frame.shape
    for lm in hand_landmarks:
        x, y = int(lm.x * w), int(lm.y * h)
        x_min, y_min = min(x, x_min), min(y, y_min)
        x_max, y_max = max(x, x_max), max(y, y_max)

    # Add padding
    padding = 20
    x_min, y_min = max(0, x_min - padding), max(0, y_min - padding)
    x_max, y_max = min(w, x_max + padding), min(h, y_max + padding)

    # Crop and resize
    hand_crop = frame[y_min:y_max, x_min:x_max]

    # Check if the crop is empty
    if hand_crop.size == 0:
        return None, results

    return hand_crop, results

# %% [markdown]
# CREATING DIRECTORIES FOR TRAINING DATA

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('Data_30_Frame_Limit_200_Videos') 

# Actions that we try to detect
actions = np.array(['zoom_in', 'reset_zoom', 'next_slide', 'prev_slide', 'annotation', 'pointer'])

# Fifty videos worth of data
no_sequences = 200

# Videos are going to be 50 frames in length
sequence_length = 30

# Folder start
start_folder = 1

# %%
for action in actions: 
    for sequence in range(0,no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# PROCESSING THE TRAINING DATA

# %%
# NEW VIDEOS WITH 30 FRAMES EACH - PROCESSING CODE

VIDEO_PATH = "training_videos"

# Function to process each video
def process_video(video_file, action, sequence_num):
    cap = cv2.VideoCapture(video_file)
    frame_count = 0

    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while True:
            ret, frame = cap.read()
            if not ret:
                break  # Stop when video ends

            # Process frame
            hand_image, results = extract_hand(frame, holistic)

            if hand_image is None:
                print(f"Warning: No hand detected in frame {frame_count} of {video_file}")
                #frame_count += 1
                keypoints = np.zeros((126,)) # saves all the keypoints as 0s if hand is not detected

            else:
                draw_styled_landmarks(hand_image, results)
                # Extract keypoints and save them
                keypoints = extract_keypoints(results)

            npy_path = os.path.join(DATA_PATH, action, str(sequence_num), str(frame_count))
            os.makedirs(os.path.dirname(npy_path), exist_ok=True)
            np.save(npy_path, keypoints)

            frame_count += 1

        cap.release()
        print(f'The total number of frames for {video_file} is {frame_count}')

# Process all video clips
for action in actions:
    action_path = os.path.join(VIDEO_PATH, action) 
    video_files = sorted(os.listdir(action_path)) 
    
    for idx, video in enumerate(video_files):
        video_file = os.path.join(action_path, video)
        print(f"Processing {video_file} for action {action} ({idx + 1}/{len(video_files)})")
        process_video(video_file, action, idx)

print("All videos processed successfully!")
cv2.destroyAllWindows()
# Out:
# Processing videos_8\zoom_in\video_1 (2).avi for action zoom_in (1/200)
# The total number of frames for videos_8\zoom_in\video_1 (2).avi is 30
# Processing videos_8\zoom_in\video_1 (3).avi for action zoom_in (2/200)
# The total number of frames for videos_8\zoom_in\video_1 (3).avi is 30
# Processing videos_8\zoom_in\video_1.avi for action zoom_in (3/200)
# The total number of frames for videos_8\zoom_in\video_1.avi is 30
# Processing videos_8\zoom_in\video_10 (2).avi for action zoom_in (4/200)
# The total number of frames for videos_8\zoom_in\video_10 (2).avi is 30
# Processing videos_8\zoom_in\video_10 (3).avi for action zoom_in (5/200)
# The total number of frames for videos_8\zoom_in\video_10 (3).avi is 30
# Processing videos_8\zoom_in\video_10 (4).avi for action zoom_in (6/200)
# The total number of frames for videos_8\zoom_in\video_10 (4).avi is 30
# Processing videos_8\zoom_in\video_10.avi for action zoom_in (7/200)
# The total number of frames for videos_8\zoom_in\video_10.avi is 30
# Processing videos_8\zoom_in\video_100.avi for action zoom_in (8/200)
# The total number of frames for videos_8\zoom_in\video_100.avi is 30
# Processing videos_8\zoom_in\video_11 (2).avi for action zoom_in (9/200)
# The total number of frames for videos_8\zoom_in\video_11 (2).avi is 30
# Processing videos_8\zoom_in\video_11 (3).avi for action zoom_in (10/200)
# The total number of frames for videos_8\zoom_in\video_11 (3).avi is 30
# Processing videos_8\zoom_in\video_11 (4).avi for action zoom_in (11/200)
# The total number of frames for videos_8\zoom_in\video_11 (4).avi is 30
# Processing videos_8\zoom_in\video_11.avi for action zoom_in (12/200)
# The total number of frames for videos_8\zoom_in\video_11.avi is 30
# Processing videos_8\zoom_in\video_12 (2).avi for action zoom_in (13/200)
# The total number of frames for videos_8\zoom_in\video_12 (2).avi is 30
# Processing videos_8\zoom_in\video_12 (3).avi for action zoom_in (14/200)
# The total number of frames for videos_8\zoom_in\video_12 (3).avi is 30
# Processing videos_8\zoom_in\video_12.avi for action zoom_in (15/200)
# The total number of frames for videos_8\zoom_in\video_12.avi is 30
# Processing videos_8\zoom_in\video_13 (2).avi for action zoom_in (16/200)
# The total number of frames for videos_8\zoom_in\video_13 (2).avi is 30
# Processing videos_8\zoom_in\video_13 (3).avi for action zoom_in (17/200)
# The total number of frames for videos_8\zoom_in\video_13 (3).avi is 30
# Processing videos_8\zoom_in\video_13 (4).avi for action zoom_in (18/200)
# The total number of frames for videos_8\zoom_in\video_13 (4).avi is 30
# Processing videos_8\zoom_in\video_13.avi for action zoom_in (19/200)
# The total number of frames for videos_8\zoom_in\video_13.avi is 30
# Processing videos_8\zoom_in\video_14 (2).avi for action zoom_in (20/200)
# The total number of frames for videos_8\zoom_in\video_14 (2).avi is 30
# Processing videos_8\zoom_in\video_14 (3).avi for action zoom_in (21/200)
# The total number of frames for videos_8\zoom_in\video_14 (3).avi is 30
# Processing videos_8\zoom_in\video_14 (4).avi for action zoom_in (22/200)
# The total number of frames for videos_8\zoom_in\video_14 (4).avi is 30
# Processing videos_8\zoom_in\video_14.avi for action zoom_in (23/200)
# The total number of frames for videos_8\zoom_in\video_14.avi is 30
# Processing videos_8\zoom_in\video_15 (2).avi for action zoom_in (24/200)
# The total number of frames for videos_8\zoom_in\video_15 (2).avi is 30
# Processing videos_8\zoom_in\video_15 (3).avi for action zoom_in (25/200)
# The total number of frames for videos_8\zoom_in\video_15 (3).avi is 30
# Processing videos_8\zoom_in\video_15 (4).avi for action zoom_in (26/200)
# The total number of frames for videos_8\zoom_in\video_15 (4).avi is 30
# Processing videos_8\zoom_in\video_15.avi for action zoom_in (27/200)
# The total number of frames for videos_8\zoom_in\video_15.avi is 30
# Processing videos_8\zoom_in\video_16 (2).avi for action zoom_in (28/200)
# The total number of frames for videos_8\zoom_in\video_16 (2).avi is 30
# Processing videos_8\zoom_in\video_16 (3).avi for action zoom_in (29/200)
# The total number of frames for videos_8\zoom_in\video_16 (3).avi is 30
# Processing videos_8\zoom_in\video_16 (4).avi for action zoom_in (30/200)
# The total number of frames for videos_8\zoom_in\video_16 (4).avi is 30
# Processing videos_8\zoom_in\video_16.avi for action zoom_in (31/200)
# The total number of frames for videos_8\zoom_in\video_16.avi is 30
# Processing videos_8\zoom_in\video_17 (2).avi for action zoom_in (32/200)
# The total number of frames for videos_8\zoom_in\video_17 (2).avi is 30
# Processing videos_8\zoom_in\video_17 (3).avi for action zoom_in (33/200)
# The total number of frames for videos_8\zoom_in\video_17 (3).avi is 30
# Processing videos_8\zoom_in\video_17.avi for action zoom_in (34/200)
# The total number of frames for videos_8\zoom_in\video_17.avi is 30
# Processing videos_8\zoom_in\video_18 (2).avi for action zoom_in (35/200)
# The total number of frames for videos_8\zoom_in\video_18 (2).avi is 30
# Processing videos_8\zoom_in\video_18 (3).avi for action zoom_in (36/200)
# The total number of frames for videos_8\zoom_in\video_18 (3).avi is 30
# Processing videos_8\zoom_in\video_18.avi for action zoom_in (37/200)
# The total number of frames for videos_8\zoom_in\video_18.avi is 30
# Processing videos_8\zoom_in\video_19 (2).avi for action zoom_in (38/200)
# The total number of frames for videos_8\zoom_in\video_19 (2).avi is 30
# Processing videos_8\zoom_in\video_19 (3).avi for action zoom_in (39/200)
# The total number of frames for videos_8\zoom_in\video_19 (3).avi is 30
# Processing videos_8\zoom_in\video_19.avi for action zoom_in (40/200)
# The total number of frames for videos_8\zoom_in\video_19.avi is 30
# Processing videos_8\zoom_in\video_2 (2).avi for action zoom_in (41/200)
# The total number of frames for videos_8\zoom_in\video_2 (2).avi is 30
# Processing videos_8\zoom_in\video_2 (3).avi for action zoom_in (42/200)
# The total number of frames for videos_8\zoom_in\video_2 (3).avi is 30
# Processing videos_8\zoom_in\video_2 (4).avi for action zoom_in (43/200)
# The total number of frames for videos_8\zoom_in\video_2 (4).avi is 30
# Processing videos_8\zoom_in\video_2 (5).avi for action zoom_in (44/200)
# The total number of frames for videos_8\zoom_in\video_2 (5).avi is 30
# Processing videos_8\zoom_in\video_2.avi for action zoom_in (45/200)
# The total number of frames for videos_8\zoom_in\video_2.avi is 30
# Processing videos_8\zoom_in\video_20 (2).avi for action zoom_in (46/200)
# The total number of frames for videos_8\zoom_in\video_20 (2).avi is 30
# Processing videos_8\zoom_in\video_20 (3).avi for action zoom_in (47/200)
# The total number of frames for videos_8\zoom_in\video_20 (3).avi is 30
# Processing videos_8\zoom_in\video_20.avi for action zoom_in (48/200)
# The total number of frames for videos_8\zoom_in\video_20.avi is 30
# Processing videos_8\zoom_in\video_21 (2).avi for action zoom_in (49/200)
# The total number of frames for videos_8\zoom_in\video_21 (2).avi is 30
# Processing videos_8\zoom_in\video_21 (3).avi for action zoom_in (50/200)
# The total number of frames for videos_8\zoom_in\video_21 (3).avi is 30
# Processing videos_8\zoom_in\video_21.avi for action zoom_in (51/200)
# The total number of frames for videos_8\zoom_in\video_21.avi is 30
# Processing videos_8\zoom_in\video_22 (2).avi for action zoom_in (52/200)
# The total number of frames for videos_8\zoom_in\video_22 (2).avi is 30
# Processing videos_8\zoom_in\video_22 (3).avi for action zoom_in (53/200)
# The total number of frames for videos_8\zoom_in\video_22 (3).avi is 30
# Processing videos_8\zoom_in\video_22.avi for action zoom_in (54/200)
# The total number of frames for videos_8\zoom_in\video_22.avi is 30
# Processing videos_8\zoom_in\video_23 (2).avi for action zoom_in (55/200)
# The total number of frames for videos_8\zoom_in\video_23 (2).avi is 30
# Processing videos_8\zoom_in\video_23 (3).avi for action zoom_in (56/200)
# The total number of frames for videos_8\zoom_in\video_23 (3).avi is 30
# Processing videos_8\zoom_in\video_23.avi for action zoom_in (57/200)
# The total number of frames for videos_8\zoom_in\video_23.avi is 30
# Processing videos_8\zoom_in\video_24 (2).avi for action zoom_in (58/200)
# The total number of frames for videos_8\zoom_in\video_24 (2).avi is 30
# Processing videos_8\zoom_in\video_24 (3).avi for action zoom_in (59/200)
# The total number of frames for videos_8\zoom_in\video_24 (3).avi is 30
# Processing videos_8\zoom_in\video_24.avi for action zoom_in (60/200)
# The total number of frames for videos_8\zoom_in\video_24.avi is 30
# Processing videos_8\zoom_in\video_25 (2).avi for action zoom_in (61/200)
# The total number of frames for videos_8\zoom_in\video_25 (2).avi is 30
# Processing videos_8\zoom_in\video_25 (3).avi for action zoom_in (62/200)
# The total number of frames for videos_8\zoom_in\video_25 (3).avi is 30
# Processing videos_8\zoom_in\video_25.avi for action zoom_in (63/200)
# The total number of frames for videos_8\zoom_in\video_25.avi is 30
# Processing videos_8\zoom_in\video_26 (2).avi for action zoom_in (64/200)
# The total number of frames for videos_8\zoom_in\video_26 (2).avi is 30
# Processing videos_8\zoom_in\video_26 (3).avi for action zoom_in (65/200)
# The total number of frames for videos_8\zoom_in\video_26 (3).avi is 30
# Processing videos_8\zoom_in\video_26.avi for action zoom_in (66/200)
# The total number of frames for videos_8\zoom_in\video_26.avi is 30
# Processing videos_8\zoom_in\video_27 (2).avi for action zoom_in (67/200)
# The total number of frames for videos_8\zoom_in\video_27 (2).avi is 30
# Processing videos_8\zoom_in\video_27 (3).avi for action zoom_in (68/200)
# The total number of frames for videos_8\zoom_in\video_27 (3).avi is 30
# Processing videos_8\zoom_in\video_27.avi for action zoom_in (69/200)
# The total number of frames for videos_8\zoom_in\video_27.avi is 30
# Processing videos_8\zoom_in\video_28 (2).avi for action zoom_in (70/200)
# The total number of frames for videos_8\zoom_in\video_28 (2).avi is 30
# Processing videos_8\zoom_in\video_28 (3).avi for action zoom_in (71/200)
# The total number of frames for videos_8\zoom_in\video_28 (3).avi is 30
# Processing videos_8\zoom_in\video_28.avi for action zoom_in (72/200)
# The total number of frames for videos_8\zoom_in\video_28.avi is 30
# Processing videos_8\zoom_in\video_29 (2).avi for action zoom_in (73/200)
# The total number of frames for videos_8\zoom_in\video_29 (2).avi is 30
# Processing videos_8\zoom_in\video_29 (3).avi for action zoom_in (74/200)
# The total number of frames for videos_8\zoom_in\video_29 (3).avi is 30
# Processing videos_8\zoom_in\video_29.avi for action zoom_in (75/200)
# The total number of frames for videos_8\zoom_in\video_29.avi is 30
# Processing videos_8\zoom_in\video_3 (2).avi for action zoom_in (76/200)
# The total number of frames for videos_8\zoom_in\video_3 (2).avi is 30
# Processing videos_8\zoom_in\video_3 (3).avi for action zoom_in (77/200)
# The total number of frames for videos_8\zoom_in\video_3 (3).avi is 30
# Processing videos_8\zoom_in\video_3 (4).avi for action zoom_in (78/200)
# The total number of frames for videos_8\zoom_in\video_3 (4).avi is 30
# Processing videos_8\zoom_in\video_3.avi for action zoom_in (79/200)
# The total number of frames for videos_8\zoom_in\video_3.avi is 30
# Processing videos_8\zoom_in\video_30 (2).avi for action zoom_in (80/200)
# The total number of frames for videos_8\zoom_in\video_30 (2).avi is 30
# Processing videos_8\zoom_in\video_30 (3).avi for action zoom_in (81/200)
# The total number of frames for videos_8\zoom_in\video_30 (3).avi is 30
# Processing videos_8\zoom_in\video_30.avi for action zoom_in (82/200)
# The total number of frames for videos_8\zoom_in\video_30.avi is 30
# Processing videos_8\zoom_in\video_31 (2).avi for action zoom_in (83/200)
# The total number of frames for videos_8\zoom_in\video_31 (2).avi is 30
# Processing videos_8\zoom_in\video_31 (3).avi for action zoom_in (84/200)
# The total number of frames for videos_8\zoom_in\video_31 (3).avi is 30
# Processing videos_8\zoom_in\video_31.avi for action zoom_in (85/200)
# The total number of frames for videos_8\zoom_in\video_31.avi is 30
# Processing videos_8\zoom_in\video_32 (2).avi for action zoom_in (86/200)
# The total number of frames for videos_8\zoom_in\video_32 (2).avi is 30
# Processing videos_8\zoom_in\video_32 (3).avi for action zoom_in (87/200)
# The total number of frames for videos_8\zoom_in\video_32 (3).avi is 30
# Processing videos_8\zoom_in\video_32.avi for action zoom_in (88/200)
# The total number of frames for videos_8\zoom_in\video_32.avi is 30
# Processing videos_8\zoom_in\video_33 (2).avi for action zoom_in (89/200)
# The total number of frames for videos_8\zoom_in\video_33 (2).avi is 30
# Processing videos_8\zoom_in\video_33 (3).avi for action zoom_in (90/200)
# The total number of frames for videos_8\zoom_in\video_33 (3).avi is 30
# Processing videos_8\zoom_in\video_33.avi for action zoom_in (91/200)
# The total number of frames for videos_8\zoom_in\video_33.avi is 30
# Processing videos_8\zoom_in\video_34 (2).avi for action zoom_in (92/200)
# The total number of frames for videos_8\zoom_in\video_34 (2).avi is 30
# Processing videos_8\zoom_in\video_34 (3).avi for action zoom_in (93/200)
# The total number of frames for videos_8\zoom_in\video_34 (3).avi is 30
# Processing videos_8\zoom_in\video_34.avi for action zoom_in (94/200)
# The total number of frames for videos_8\zoom_in\video_34.avi is 30
# Processing videos_8\zoom_in\video_35 (2).avi for action zoom_in (95/200)
# The total number of frames for videos_8\zoom_in\video_35 (2).avi is 30
# Processing videos_8\zoom_in\video_35 (3).avi for action zoom_in (96/200)
# The total number of frames for videos_8\zoom_in\video_35 (3).avi is 30
# Processing videos_8\zoom_in\video_35.avi for action zoom_in (97/200)
# The total number of frames for videos_8\zoom_in\video_35.avi is 30
# Processing videos_8\zoom_in\video_36 (2).avi for action zoom_in (98/200)
# The total number of frames for videos_8\zoom_in\video_36 (2).avi is 30
# Processing videos_8\zoom_in\video_36 (3).avi for action zoom_in (99/200)
# The total number of frames for videos_8\zoom_in\video_36 (3).avi is 30
# Processing videos_8\zoom_in\video_36.avi for action zoom_in (100/200)
# The total number of frames for videos_8\zoom_in\video_36.avi is 30
# Processing videos_8\zoom_in\video_37 (2).avi for action zoom_in (101/200)
# The total number of frames for videos_8\zoom_in\video_37 (2).avi is 30
# Processing videos_8\zoom_in\video_37 (3).avi for action zoom_in (102/200)
# The total number of frames for videos_8\zoom_in\video_37 (3).avi is 30
# Processing videos_8\zoom_in\video_37.avi for action zoom_in (103/200)
# The total number of frames for videos_8\zoom_in\video_37.avi is 30
# Processing videos_8\zoom_in\video_38 (2).avi for action zoom_in (104/200)
# The total number of frames for videos_8\zoom_in\video_38 (2).avi is 30
# Processing videos_8\zoom_in\video_38 (3).avi for action zoom_in (105/200)
# The total number of frames for videos_8\zoom_in\video_38 (3).avi is 30
# Processing videos_8\zoom_in\video_38.avi for action zoom_in (106/200)
# The total number of frames for videos_8\zoom_in\video_38.avi is 30
# Processing videos_8\zoom_in\video_39 (2).avi for action zoom_in (107/200)
# The total number of frames for videos_8\zoom_in\video_39 (2).avi is 30
# Processing videos_8\zoom_in\video_39 (3).avi for action zoom_in (108/200)
# The total number of frames for videos_8\zoom_in\video_39 (3).avi is 30
# Processing videos_8\zoom_in\video_39.avi for action zoom_in (109/200)
# The total number of frames for videos_8\zoom_in\video_39.avi is 30
# Processing videos_8\zoom_in\video_4 (2).avi for action zoom_in (110/200)
# The total number of frames for videos_8\zoom_in\video_4 (2).avi is 30
# Processing videos_8\zoom_in\video_4 (3).avi for action zoom_in (111/200)
# The total number of frames for videos_8\zoom_in\video_4 (3).avi is 30
# Processing videos_8\zoom_in\video_4 (4).avi for action zoom_in (112/200)
# The total number of frames for videos_8\zoom_in\video_4 (4).avi is 30
# Processing videos_8\zoom_in\video_4.avi for action zoom_in (113/200)
# The total number of frames for videos_8\zoom_in\video_4.avi is 30
# Processing videos_8\zoom_in\video_40 (2).avi for action zoom_in (114/200)
# The total number of frames for videos_8\zoom_in\video_40 (2).avi is 30
# Processing videos_8\zoom_in\video_40 (3).avi for action zoom_in (115/200)
# The total number of frames for videos_8\zoom_in\video_40 (3).avi is 30
# Processing videos_8\zoom_in\video_40.avi for action zoom_in (116/200)
# The total number of frames for videos_8\zoom_in\video_40.avi is 30
# Processing videos_8\zoom_in\video_41 (2).avi for action zoom_in (117/200)
# The total number of frames for videos_8\zoom_in\video_41 (2).avi is 30
# Processing videos_8\zoom_in\video_41 (3).avi for action zoom_in (118/200)
# The total number of frames for videos_8\zoom_in\video_41 (3).avi is 30
# Processing videos_8\zoom_in\video_41.avi for action zoom_in (119/200)
# The total number of frames for videos_8\zoom_in\video_41.avi is 30
# Processing videos_8\zoom_in\video_42 (2).avi for action zoom_in (120/200)
# The total number of frames for videos_8\zoom_in\video_42 (2).avi is 30
# Processing videos_8\zoom_in\video_42 (3).avi for action zoom_in (121/200)
# The total number of frames for videos_8\zoom_in\video_42 (3).avi is 30
# Processing videos_8\zoom_in\video_42.avi for action zoom_in (122/200)
# The total number of frames for videos_8\zoom_in\video_42.avi is 30
# Processing videos_8\zoom_in\video_43 (2).avi for action zoom_in (123/200)
# The total number of frames for videos_8\zoom_in\video_43 (2).avi is 30
# Processing videos_8\zoom_in\video_43.avi for action zoom_in (124/200)
# The total number of frames for videos_8\zoom_in\video_43.avi is 30
# Processing videos_8\zoom_in\video_44 (2).avi for action zoom_in (125/200)
# The total number of frames for videos_8\zoom_in\video_44 (2).avi is 30
# Processing videos_8\zoom_in\video_44 (3).avi for action zoom_in (126/200)
# The total number of frames for videos_8\zoom_in\video_44 (3).avi is 30
# Processing videos_8\zoom_in\video_44.avi for action zoom_in (127/200)
# The total number of frames for videos_8\zoom_in\video_44.avi is 30
# Processing videos_8\zoom_in\video_45 (2).avi for action zoom_in (128/200)
# The total number of frames for videos_8\zoom_in\video_45 (2).avi is 30
# Processing videos_8\zoom_in\video_45.avi for action zoom_in (129/200)
# The total number of frames for videos_8\zoom_in\video_45.avi is 30
# Processing videos_8\zoom_in\video_46 (2).avi for action zoom_in (130/200)
# ⚠️ Warning: No hand detected in frame 0 of videos_8\zoom_in\video_46 (2).avi
# ⚠️ Warning: No hand detected in frame 1 of videos_8\zoom_in\video_46 (2).avi
# ⚠️ Warning: No hand detected in frame 2 of videos_8\zoom_in\video_46 (2).avi
# ⚠️ Warning: No hand detected in frame 3 of videos_8\zoom_in\video_46 (2).avi
# ⚠️ Warning: No hand detected in frame 4 of videos_8\zoom_in\video_46 (2).avi
# ⚠️ Warning: No hand detected in frame 5 of videos_8\zoom_in\video_46 (2).avi
# ⚠️ Warning: No hand detected in frame 6 of videos_8\zoom_in\video_46 (2).avi
# ⚠️ Warning: No hand detected in frame 7 of videos_8\zoom_in\video_46 (2).avi
# ⚠️ Warning: No hand detected in frame 8 of videos_8\zoom_in\video_46 (2).avi
# ⚠️ Warning: No hand detected in frame 9 of videos_8\zoom_in\video_46 (2).avi
# ⚠️ Warning: No hand detected in frame 10 of videos_8\zoom_in\video_46 (2).avi
# The total number of frames for videos_8\zoom_in\video_46 (2).avi is 30
# Processing videos_8\zoom_in\video_46 (3).avi for action zoom_in (131/200)
# The total number of frames for videos_8\zoom_in\video_46 (3).avi is 30
# Processing videos_8\zoom_in\video_46.avi for action zoom_in (132/200)
# The total number of frames for videos_8\zoom_in\video_46.avi is 30
# Processing videos_8\zoom_in\video_47.avi for action zoom_in (133/200)
# The total number of frames for videos_8\zoom_in\video_47.avi is 30
# Processing videos_8\zoom_in\video_48.avi for action zoom_in (134/200)
# The total number of frames for videos_8\zoom_in\video_48.avi is 30
# Processing videos_8\zoom_in\video_49 (2).avi for action zoom_in (135/200)
# The total number of frames for videos_8\zoom_in\video_49 (2).avi is 30
# Processing videos_8\zoom_in\video_49.avi for action zoom_in (136/200)
# The total number of frames for videos_8\zoom_in\video_49.avi is 30
# Processing videos_8\zoom_in\video_5 (2).avi for action zoom_in (137/200)
# The total number of frames for videos_8\zoom_in\video_5 (2).avi is 30
# Processing videos_8\zoom_in\video_5 (3).avi for action zoom_in (138/200)
# The total number of frames for videos_8\zoom_in\video_5 (3).avi is 30
# Processing videos_8\zoom_in\video_5.avi for action zoom_in (139/200)
# The total number of frames for videos_8\zoom_in\video_5.avi is 30
# Processing videos_8\zoom_in\video_50 (2).avi for action zoom_in (140/200)
# The total number of frames for videos_8\zoom_in\video_50 (2).avi is 30
# Processing videos_8\zoom_in\video_50.avi for action zoom_in (141/200)
# The total number of frames for videos_8\zoom_in\video_50.avi is 30
# Processing videos_8\zoom_in\video_51.avi for action zoom_in (142/200)
# The total number of frames for videos_8\zoom_in\video_51.avi is 30
# Processing videos_8\zoom_in\video_52.avi for action zoom_in (143/200)
# The total number of frames for videos_8\zoom_in\video_52.avi is 30
# Processing videos_8\zoom_in\video_53.avi for action zoom_in (144/200)
# The total number of frames for videos_8\zoom_in\video_53.avi is 30
# Processing videos_8\zoom_in\video_54.avi for action zoom_in (145/200)
# The total number of frames for videos_8\zoom_in\video_54.avi is 30
# Processing videos_8\zoom_in\video_55.avi for action zoom_in (146/200)
# The total number of frames for videos_8\zoom_in\video_55.avi is 30
# Processing videos_8\zoom_in\video_56.avi for action zoom_in (147/200)
# The total number of frames for videos_8\zoom_in\video_56.avi is 30
# Processing videos_8\zoom_in\video_57.avi for action zoom_in (148/200)
# The total number of frames for videos_8\zoom_in\video_57.avi is 30
# Processing videos_8\zoom_in\video_58.avi for action zoom_in (149/200)
# The total number of frames for videos_8\zoom_in\video_58.avi is 30
# Processing videos_8\zoom_in\video_59.avi for action zoom_in (150/200)
# The total number of frames for videos_8\zoom_in\video_59.avi is 30
# Processing videos_8\zoom_in\video_6 (2).avi for action zoom_in (151/200)
# The total number of frames for videos_8\zoom_in\video_6 (2).avi is 30
# Processing videos_8\zoom_in\video_6 (3).avi for action zoom_in (152/200)
# The total number of frames for videos_8\zoom_in\video_6 (3).avi is 30
# Processing videos_8\zoom_in\video_6.avi for action zoom_in (153/200)
# The total number of frames for videos_8\zoom_in\video_6.avi is 30
# Processing videos_8\zoom_in\video_60.avi for action zoom_in (154/200)
# The total number of frames for videos_8\zoom_in\video_60.avi is 30
# Processing videos_8\zoom_in\video_61.avi for action zoom_in (155/200)
# The total number of frames for videos_8\zoom_in\video_61.avi is 30
# Processing videos_8\zoom_in\video_62.avi for action zoom_in (156/200)
# The total number of frames for videos_8\zoom_in\video_62.avi is 30
# Processing videos_8\zoom_in\video_63.avi for action zoom_in (157/200)
# The total number of frames for videos_8\zoom_in\video_63.avi is 30
# Processing videos_8\zoom_in\video_64.avi for action zoom_in (158/200)
# The total number of frames for videos_8\zoom_in\video_64.avi is 30
# Processing videos_8\zoom_in\video_65.avi for action zoom_in (159/200)
# The total number of frames for videos_8\zoom_in\video_65.avi is 30
# Processing videos_8\zoom_in\video_66.avi for action zoom_in (160/200)
# The total number of frames for videos_8\zoom_in\video_66.avi is 30
# Processing videos_8\zoom_in\video_67.avi for action zoom_in (161/200)
# The total number of frames for videos_8\zoom_in\video_67.avi is 30
# Processing videos_8\zoom_in\video_68.avi for action zoom_in (162/200)
# The total number of frames for videos_8\zoom_in\video_68.avi is 30
# Processing videos_8\zoom_in\video_69.avi for action zoom_in (163/200)
# The total number of frames for videos_8\zoom_in\video_69.avi is 30
# Processing videos_8\zoom_in\video_7 (2).avi for action zoom_in (164/200)
# ⚠️ Warning: No hand detected in frame 0 of videos_8\zoom_in\video_7 (2).avi
# The total number of frames for videos_8\zoom_in\video_7 (2).avi is 30
# Processing videos_8\zoom_in\video_7 (3).avi for action zoom_in (165/200)
# ⚠️ Warning: No hand detected in frame 7 of videos_8\zoom_in\video_7 (3).avi
# ⚠️ Warning: No hand detected in frame 12 of videos_8\zoom_in\video_7 (3).avi
# ⚠️ Warning: No hand detected in frame 13 of videos_8\zoom_in\video_7 (3).avi
# ⚠️ Warning: No hand detected in frame 14 of videos_8\zoom_in\video_7 (3).avi
# The total number of frames for videos_8\zoom_in\video_7 (3).avi is 30
# Processing videos_8\zoom_in\video_7.avi for action zoom_in (166/200)
# The total number of frames for videos_8\zoom_in\video_7.avi is 30
# Processing videos_8\zoom_in\video_70.avi for action zoom_in (167/200)
# The total number of frames for videos_8\zoom_in\video_70.avi is 30
# Processing videos_8\zoom_in\video_71.avi for action zoom_in (168/200)
# The total number of frames for videos_8\zoom_in\video_71.avi is 30
# Processing videos_8\zoom_in\video_72.avi for action zoom_in (169/200)
# The total number of frames for videos_8\zoom_in\video_72.avi is 30
# Processing videos_8\zoom_in\video_73.avi for action zoom_in (170/200)
# The total number of frames for videos_8\zoom_in\video_73.avi is 30
# Processing videos_8\zoom_in\video_74.avi for action zoom_in (171/200)
# The total number of frames for videos_8\zoom_in\video_74.avi is 30
# Processing videos_8\zoom_in\video_75.avi for action zoom_in (172/200)
# The total number of frames for videos_8\zoom_in\video_75.avi is 30
# Processing videos_8\zoom_in\video_76.avi for action zoom_in (173/200)
# The total number of frames for videos_8\zoom_in\video_76.avi is 30
# Processing videos_8\zoom_in\video_77.avi for action zoom_in (174/200)
# The total number of frames for videos_8\zoom_in\video_77.avi is 30
# Processing videos_8\zoom_in\video_78.avi for action zoom_in (175/200)
# The total number of frames for videos_8\zoom_in\video_78.avi is 30
# Processing videos_8\zoom_in\video_79.avi for action zoom_in (176/200)
# The total number of frames for videos_8\zoom_in\video_79.avi is 30
# Processing videos_8\zoom_in\video_8 (2).avi for action zoom_in (177/200)
# ⚠️ Warning: No hand detected in frame 2 of videos_8\zoom_in\video_8 (2).avi
# ⚠️ Warning: No hand detected in frame 3 of videos_8\zoom_in\video_8 (2).avi
# ⚠️ Warning: No hand detected in frame 4 of videos_8\zoom_in\video_8 (2).avi
# ⚠️ Warning: No hand detected in frame 5 of videos_8\zoom_in\video_8 (2).avi
# ⚠️ Warning: No hand detected in frame 6 of videos_8\zoom_in\video_8 (2).avi
# ⚠️ Warning: No hand detected in frame 7 of videos_8\zoom_in\video_8 (2).avi
# The total number of frames for videos_8\zoom_in\video_8 (2).avi is 30
# Processing videos_8\zoom_in\video_8.avi for action zoom_in (178/200)
# The total number of frames for videos_8\zoom_in\video_8.avi is 30
# Processing videos_8\zoom_in\video_80.avi for action zoom_in (179/200)
# The total number of frames for videos_8\zoom_in\video_80.avi is 30
# Processing videos_8\zoom_in\video_81.avi for action zoom_in (180/200)
# The total number of frames for videos_8\zoom_in\video_81.avi is 30
# Processing videos_8\zoom_in\video_82.avi for action zoom_in (181/200)
# The total number of frames for videos_8\zoom_in\video_82.avi is 30
# Processing videos_8\zoom_in\video_83.avi for action zoom_in (182/200)
# The total number of frames for videos_8\zoom_in\video_83.avi is 30
# Processing videos_8\zoom_in\video_84.avi for action zoom_in (183/200)
# The total number of frames for videos_8\zoom_in\video_84.avi is 30
# Processing videos_8\zoom_in\video_85.avi for action zoom_in (184/200)
# The total number of frames for videos_8\zoom_in\video_85.avi is 30
# Processing videos_8\zoom_in\video_86.avi for action zoom_in (185/200)
# The total number of frames for videos_8\zoom_in\video_86.avi is 30
# Processing videos_8\zoom_in\video_87.avi for action zoom_in (186/200)
# The total number of frames for videos_8\zoom_in\video_87.avi is 30
# Processing videos_8\zoom_in\video_88.avi for action zoom_in (187/200)
# The total number of frames for videos_8\zoom_in\video_88.avi is 30
# Processing videos_8\zoom_in\video_89.avi for action zoom_in (188/200)
# The total number of frames for videos_8\zoom_in\video_89.avi is 30
# Processing videos_8\zoom_in\video_9 (2).avi for action zoom_in (189/200)
# The total number of frames for videos_8\zoom_in\video_9 (2).avi is 30
# Processing videos_8\zoom_in\video_9.avi for action zoom_in (190/200)
# The total number of frames for videos_8\zoom_in\video_9.avi is 30
# Processing videos_8\zoom_in\video_90.avi for action zoom_in (191/200)
# The total number of frames for videos_8\zoom_in\video_90.avi is 30
# Processing videos_8\zoom_in\video_91.avi for action zoom_in (192/200)
# The total number of frames for videos_8\zoom_in\video_91.avi is 30
# Processing videos_8\zoom_in\video_92.avi for action zoom_in (193/200)
# The total number of frames for videos_8\zoom_in\video_92.avi is 30
# Processing videos_8\zoom_in\video_93.avi for action zoom_in (194/200)
# The total number of frames for videos_8\zoom_in\video_93.avi is 30
# Processing videos_8\zoom_in\video_94.avi for action zoom_in (195/200)
# The total number of frames for videos_8\zoom_in\video_94.avi is 30
# Processing videos_8\zoom_in\video_95.avi for action zoom_in (196/200)
# The total number of frames for videos_8\zoom_in\video_95.avi is 30
# Processing videos_8\zoom_in\video_96.avi for action zoom_in (197/200)
# The total number of frames for videos_8\zoom_in\video_96.avi is 30
# Processing videos_8\zoom_in\video_97.avi for action zoom_in (198/200)
# The total number of frames for videos_8\zoom_in\video_97.avi is 30
# Processing videos_8\zoom_in\video_98.avi for action zoom_in (199/200)
# The total number of frames for videos_8\zoom_in\video_98.avi is 30
# Processing videos_8\zoom_in\video_99.avi for action zoom_in (200/200)
# The total number of frames for videos_8\zoom_in\video_99.avi is 30
# Processing videos_8\reset_zoom\video_1 (2).avi for action reset_zoom (1/200)
# The total number of frames for videos_8\reset_zoom\video_1 (2).avi is 30
# Processing videos_8\reset_zoom\video_1.avi for action reset_zoom (2/200)
# The total number of frames for videos_8\reset_zoom\video_1.avi is 30
# Processing videos_8\reset_zoom\video_10.avi for action reset_zoom (3/200)
# ⚠️ Warning: No hand detected in frame 0 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 1 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 2 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 3 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 4 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 5 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 6 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 7 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 8 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 9 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 10 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 11 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 12 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 13 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 14 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 15 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 16 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 17 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 18 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 19 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 20 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 21 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 22 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 23 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 24 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 25 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 26 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 27 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 28 of videos_8\reset_zoom\video_10.avi
# ⚠️ Warning: No hand detected in frame 29 of videos_8\reset_zoom\video_10.avi
# The total number of frames for videos_8\reset_zoom\video_10.avi is 30
# Processing videos_8\reset_zoom\video_100 (2).avi for action reset_zoom (4/200)
# The total number of frames for videos_8\reset_zoom\video_100 (2).avi is 30
# Processing videos_8\reset_zoom\video_100.avi for action reset_zoom (5/200)
# The total number of frames for videos_8\reset_zoom\video_100.avi is 30
# Processing videos_8\reset_zoom\video_11 (2).avi for action reset_zoom (6/200)
# ⚠️ Warning: No hand detected in frame 9 of videos_8\reset_zoom\video_11 (2).avi
# ⚠️ Warning: No hand detected in frame 22 of videos_8\reset_zoom\video_11 (2).avi
# ⚠️ Warning: No hand detected in frame 23 of videos_8\reset_zoom\video_11 (2).avi
# ⚠️ Warning: No hand detected in frame 24 of videos_8\reset_zoom\video_11 (2).avi
# The total number of frames for videos_8\reset_zoom\video_11 (2).avi is 30
# Processing videos_8\reset_zoom\video_11.avi for action reset_zoom (7/200)
# The total number of frames for videos_8\reset_zoom\video_11.avi is 30
# Processing videos_8\reset_zoom\video_12 (2).avi for action reset_zoom (8/200)
# ⚠️ Warning: No hand detected in frame 7 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 8 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 9 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 10 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 11 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 12 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 13 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 14 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 15 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 16 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 17 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 18 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 19 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 20 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 21 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 22 of videos_8\reset_zoom\video_12 (2).avi
# ⚠️ Warning: No hand detected in frame 23 of videos_8\reset_zoom\video_12 (2).avi
# The total number of frames for videos_8\reset_zoom\video_12 (2).avi is 30
# Processing videos_8\reset_zoom\video_12.avi for action reset_zoom (9/200)
# The total number of frames for videos_8\reset_zoom\video_12.avi is 30
# Processing videos_8\reset_zoom\video_13 (2).avi for action reset_zoom (10/200)
# ⚠️ Warning: No hand detected in frame 0 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 1 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 2 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 11 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 12 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 13 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 14 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 15 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 22 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 23 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 24 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 25 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 26 of videos_8\reset_zoom\video_13 (2).avi
# ⚠️ Warning: No hand detected in frame 27 of videos_8\reset_zoom\video_13 (2).avi
# The total number of frames for videos_8\reset_zoom\video_13 (2).avi is 30
# Processing videos_8\reset_zoom\video_13.avi for action reset_zoom (11/200)
# The total number of frames for videos_8\reset_zoom\video_13.avi is 30
# Processing videos_8\reset_zoom\video_14 (2).avi for action reset_zoom (12/200)
# ⚠️ Warning: No hand detected in frame 0 of videos_8\reset_zoom\video_14 (2).avi
# ⚠️ Warning: No hand detected in frame 3 of videos_8\reset_zoom\video_14 (2).avi
# ⚠️ Warning: No hand detected in frame 11 of videos_8\reset_zoom\video_14 (2).avi
# ⚠️ Warning: No hand detected in frame 17 of videos_8\reset_zoom\video_14 (2).avi
# ⚠️ Warning: No hand detected in frame 20 of videos_8\reset_zoom\video_14 (2).avi
# ⚠️ Warning: No hand detected in frame 21 of videos_8\reset_zoom\video_14 (2).avi
# ⚠️ Warning: No hand detected in frame 22 of videos_8\reset_zoom\video_14 (2).avi
# ⚠️ Warning: No hand detected in frame 23 of videos_8\reset_zoom\video_14 (2).avi
# ⚠️ Warning: No hand detected in frame 24 of videos_8\reset_zoom\video_14 (2).avi
# ⚠️ Warning: No hand detected in frame 25 of videos_8\reset_zoom\video_14 (2).avi
# ⚠️ Warning: No hand detected in frame 26 of videos_8\reset_zoom\video_14 (2).avi
# The total number of frames for videos_8\reset_zoom\video_14 (2).avi is 30
# Processing videos_8\reset_zoom\video_14.avi for action reset_zoom (13/200)
# The total number of frames for videos_8\reset_zoom\video_14.avi is 30
# Processing videos_8\reset_zoom\video_15 (2).avi for action reset_zoom (14/200)
# The total number of frames for videos_8\reset_zoom\video_15 (2).avi is 30
# Processing videos_8\reset_zoom\video_15.avi for action reset_zoom (15/200)
# The total number of frames for videos_8\reset_zoom\video_15.avi is 30
# Processing videos_8\reset_zoom\video_16 (2).avi for action reset_zoom (16/200)
# The total number of frames for videos_8\reset_zoom\video_16 (2).avi is 30
# Processing videos_8\reset_zoom\video_16.avi for action reset_zoom (17/200)
# The total number of frames for videos_8\reset_zoom\video_16.avi is 30
# Processing videos_8\reset_zoom\video_17 (2).avi for action reset_zoom (18/200)
# The total number of frames for videos_8\reset_zoom\video_17 (2).avi is 30
# Processing videos_8\reset_zoom\video_17.avi for action reset_zoom (19/200)
# The total number of frames for videos_8\reset_zoom\video_17.avi is 30
# Processing videos_8\reset_zoom\video_18 (2).avi for action reset_zoom (20/200)
# The total number of frames for videos_8\reset_zoom\video_18 (2).avi is 30
# Processing videos_8\reset_zoom\video_18.avi for action reset_zoom (21/200)
# The total number of frames for videos_8\reset_zoom\video_18.avi is 30
# Processing videos_8\reset_zoom\video_19 (2).avi for action reset_zoom (22/200)
# The total number of frames for videos_8\reset_zoom\video_19 (2).avi is 30
# Processing videos_8\reset_zoom\video_19.avi for action reset_zoom (23/200)
# The total number of frames for videos_8\reset_zoom\video_19.avi is 30
# Processing videos_8\reset_zoom\video_2 (2).avi for action reset_zoom (24/200)
# The total number of frames for videos_8\reset_zoom\video_2 (2).avi is 30
# Processing videos_8\reset_zoom\video_2 (3).avi for action reset_zoom (25/200)
# ⚠️ Warning: No hand detected in frame 0 of videos_8\reset_zoom\video_2 (3).avi
# The total number of frames for videos_8\reset_zoom\video_2 (3).avi is 30
# Processing videos_8\reset_zoom\video_2 (4).avi for action reset_zoom (26/200)
# The total number of frames for videos_8\reset_zoom\video_2 (4).avi is 30
# Processing videos_8\reset_zoom\video_2.avi for action reset_zoom (27/200)
# The total number of frames for videos_8\reset_zoom\video_2.avi is 30
# Processing videos_8\reset_zoom\video_20 (2).avi for action reset_zoom (28/200)
# The total number of frames for videos_8\reset_zoom\video_20 (2).avi is 30
# Processing videos_8\reset_zoom\video_20.avi for action reset_zoom (29/200)
# The total number of frames for videos_8\reset_zoom\video_20.avi is 30
# Processing videos_8\reset_zoom\video_21 (2).avi for action reset_zoom (30/200)
# The total number of frames for videos_8\reset_zoom\video_21 (2).avi is 30
# Processing videos_8\reset_zoom\video_21.avi for action reset_zoom (31/200)
# The total number of frames for videos_8\reset_zoom\video_21.avi is 30
# Processing videos_8\reset_zoom\video_22 (2).avi for action reset_zoom (32/200)
# The total number of frames for videos_8\reset_zoom\video_22 (2).avi is 30
# Processing videos_8\reset_zoom\video_22.avi for action reset_zoom (33/200)
# The total number of frames for videos_8\reset_zoom\video_22.avi is 30
# Processing videos_8\reset_zoom\video_23 (2).avi for action reset_zoom (34/200)
# The total number of frames for videos_8\reset_zoom\video_23 (2).avi is 30
# Processing videos_8\reset_zoom\video_23.avi for action reset_zoom (35/200)
# The total number of frames for videos_8\reset_zoom\video_23.avi is 30
# Processing videos_8\reset_zoom\video_24.avi for action reset_zoom (36/200)
# The total number of frames for videos_8\reset_zoom\video_24.avi is 30
# Processing videos_8\reset_zoom\video_25.avi for action reset_zoom (37/200)
# The total number of frames for videos_8\reset_zoom\video_25.avi is 30
# Processing videos_8\reset_zoom\video_26 (2).avi for action reset_zoom (38/200)
# The total number of frames for videos_8\reset_zoom\video_26 (2).avi is 30
# Processing videos_8\reset_zoom\video_26.avi for action reset_zoom (39/200)
# The total number of frames for videos_8\reset_zoom\video_26.avi is 30
# Processing videos_8\reset_zoom\video_27 (2).avi for action reset_zoom (40/200)
# The total number of frames for videos_8\reset_zoom\video_27 (2).avi is 30
# Processing videos_8\reset_zoom\video_27.avi for action reset_zoom (41/200)
# The total number of frames for videos_8\reset_zoom\video_27.avi is 30
# Processing videos_8\reset_zoom\video_28 (2).avi for action reset_zoom (42/200)
# The total number of frames for videos_8\reset_zoom\video_28 (2).avi is 30
# Processing videos_8\reset_zoom\video_28.avi for action reset_zoom (43/200)
# The total number of frames for videos_8\reset_zoom\video_28.avi is 30
# Processing videos_8\reset_zoom\video_29 (2).avi for action reset_zoom (44/200)
# The total number of frames for videos_8\reset_zoom\video_29 (2).avi is 30
# Processing videos_8\reset_zoom\video_29.avi for action reset_zoom (45/200)
# The total number of frames for videos_8\reset_zoom\video_29.avi is 30
# Processing videos_8\reset_zoom\video_3 (2).avi for action reset_zoom (46/200)
# The total number of frames for videos_8\reset_zoom\video_3 (2).avi is 30
# Processing videos_8\reset_zoom\video_3 (3).avi for action reset_zoom (47/200)
# ⚠️ Warning: No hand detected in frame 5 of videos_8\reset_zoom\video_3 (3).avi
# ⚠️ Warning: No hand detected in frame 23 of videos_8\reset_zoom\video_3 (3).avi
# The total number of frames for videos_8\reset_zoom\video_3 (3).avi is 30
# Processing videos_8\reset_zoom\video_3.avi for action reset_zoom (48/200)
# The total number of frames for videos_8\reset_zoom\video_3.avi is 30
# Processing videos_8\reset_zoom\video_30 (2).avi for action reset_zoom (49/200)
# The total number of frames for videos_8\reset_zoom\video_30 (2).avi is 30
# Processing videos_8\reset_zoom\video_30.avi for action reset_zoom (50/200)
# The total number of frames for videos_8\reset_zoom\video_30.avi is 30
# Processing videos_8\reset_zoom\video_31 (2).avi for action reset_zoom (51/200)
# The total number of frames for videos_8\reset_zoom\video_31 (2).avi is 30
# Processing videos_8\reset_zoom\video_31.avi for action reset_zoom (52/200)
# The total number of frames for videos_8\reset_zoom\video_31.avi is 30
# Processing videos_8\reset_zoom\video_32 (2).avi for action reset_zoom (53/200)
# The total number of frames for videos_8\reset_zoom\video_32 (2).avi is 30
# Processing videos_8\reset_zoom\video_32.avi for action reset_zoom (54/200)
# The total number of frames for videos_8\reset_zoom\video_32.avi is 30
# Processing videos_8\reset_zoom\video_33 (2).avi for action reset_zoom (55/200)
# The total number of frames for videos_8\reset_zoom\video_33 (2).avi is 30
# Processing videos_8\reset_zoom\video_33.avi for action reset_zoom (56/200)
# The total number of frames for videos_8\reset_zoom\video_33.avi is 30
# Processing videos_8\reset_zoom\video_34 (2).avi for action reset_zoom (57/200)
# The total number of frames for videos_8\reset_zoom\video_34 (2).avi is 30
# Processing videos_8\reset_zoom\video_34.avi for action reset_zoom (58/200)
# The total number of frames for videos_8\reset_zoom\video_34.avi is 30
# Processing videos_8\reset_zoom\video_35 (2).avi for action reset_zoom (59/200)
# The total number of frames for videos_8\reset_zoom\video_35 (2).avi is 30
# Processing videos_8\reset_zoom\video_35.avi for action reset_zoom (60/200)
# The total number of frames for videos_8\reset_zoom\video_35.avi is 30
# Processing videos_8\reset_zoom\video_36 (2).avi for action reset_zoom (61/200)
# The total number of frames for videos_8\reset_zoom\video_36 (2).avi is 30
# Processing videos_8\reset_zoom\video_36.avi for action reset_zoom (62/200)
# The total number of frames for videos_8\reset_zoom\video_36.avi is 30
# Processing videos_8\reset_zoom\video_37 (2).avi for action reset_zoom (63/200)
# The total number of frames for videos_8\reset_zoom\video_37 (2).avi is 30
# Processing videos_8\reset_zoom\video_37.avi for action reset_zoom (64/200)
# The total number of frames for videos_8\reset_zoom\video_37.avi is 30
# Processing videos_8\reset_zoom\video_38 (2).avi for action reset_zoom (65/200)
# The total number of frames for videos_8\reset_zoom\video_38 (2).avi is 30
# Processing videos_8\reset_zoom\video_38.avi for action reset_zoom (66/200)
# The total number of frames for videos_8\reset_zoom\video_38.avi is 30
# Processing videos_8\reset_zoom\video_39 (2).avi for action reset_zoom (67/200)
# The total number of frames for videos_8\reset_zoom\video_39 (2).avi is 30
# Processing videos_8\reset_zoom\video_39.avi for action reset_zoom (68/200)
# The total number of frames for videos_8\reset_zoom\video_39.avi is 30
# Processing videos_8\reset_zoom\video_4 (2).avi for action reset_zoom (69/200)
# ⚠️ Warning: No hand detected in frame 0 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 5 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 12 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 13 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 14 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 15 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 16 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 17 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 22 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 23 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 24 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 25 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 26 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 27 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 28 of videos_8\reset_zoom\video_4 (2).avi
# ⚠️ Warning: No hand detected in frame 29 of videos_8\reset_zoom\video_4 (2).avi
# The total number of frames for videos_8\reset_zoom\video_4 (2).avi is 30
# Processing videos_8\reset_zoom\video_4.avi for action reset_zoom (70/200)
# The total number of frames for videos_8\reset_zoom\video_4.avi is 30
# Processing videos_8\reset_zoom\video_40 (2).avi for action reset_zoom (71/200)
# The total number of frames for videos_8\reset_zoom\video_40 (2).avi is 30
# Processing videos_8\reset_zoom\video_40.avi for action reset_zoom (72/200)
# The total number of frames for videos_8\reset_zoom\video_40.avi is 30
# ...
# Processing videos_8\pointer\video_35.avi for action pointer (87/200)
# The total number of frames for videos_8\pointer\video_35.avi is 30
# Processing videos_8\pointer\video_36 (2).avi for action pointer (88/200)
# The total number of frames for videos_8\pointer\video_36 (2).avi is 30
# Processing videos_8\pointer\video_36 (3).avi for action pointer (89/200)
# The total number of frames for videos_8\pointer\video_36 (3).avi is 30
# Processing videos_8\pointer\video_36.avi for action pointer (90/200)
# The total number of frames for videos_8\pointer\video_36.avi is 30
# Processing videos_8\pointer\video_37 (2).avi for action pointer (91/200)
# The total number of frames for videos_8\pointer\video_37 (2).avi is 30
# Processing videos_8\pointer\video_37 (3).avi for action pointer (92/200)
# The total number of frames for videos_8\pointer\video_37 (3).avi is 30
# Processing videos_8\pointer\video_37.avi for action pointer (93/200)
# The total number of frames for videos_8\pointer\video_37.avi is 30
# Processing videos_8\pointer\video_38 (2).avi for action pointer (94/200)
# The total number of frames for videos_8\pointer\video_38 (2).avi is 30
# Processing videos_8\pointer\video_38 (3).avi for action pointer (95/200)
# The total number of frames for videos_8\pointer\video_38 (3).avi is 30
# Processing videos_8\pointer\video_38.avi for action pointer (96/200)
# The total number of frames for videos_8\pointer\video_38.avi is 30
# Processing videos_8\pointer\video_39 (2).avi for action pointer (97/200)
# The total number of frames for videos_8\pointer\video_39 (2).avi is 30
# Processing videos_8\pointer\video_39.avi for action pointer (98/200)
# The total number of frames for videos_8\pointer\video_39.avi is 30
# Processing videos_8\pointer\video_4 (2).avi for action pointer (99/200)
# The total number of frames for videos_8\pointer\video_4 (2).avi is 30
# Processing videos_8\pointer\video_4.avi for action pointer (100/200)
# The total number of frames for videos_8\pointer\video_4.avi is 30
# Processing videos_8\pointer\video_40 (2).avi for action pointer (101/200)
# The total number of frames for videos_8\pointer\video_40 (2).avi is 30
# Processing videos_8\pointer\video_40 (3).avi for action pointer (102/200)
# The total number of frames for videos_8\pointer\video_40 (3).avi is 30
# Processing videos_8\pointer\video_40.avi for action pointer (103/200)
# The total number of frames for videos_8\pointer\video_40.avi is 30
# Processing videos_8\pointer\video_41 (2).avi for action pointer (104/200)
# The total number of frames for videos_8\pointer\video_41 (2).avi is 30
# Processing videos_8\pointer\video_41 (3).avi for action pointer (105/200)
# The total number of frames for videos_8\pointer\video_41 (3).avi is 30
# Processing videos_8\pointer\video_41.avi for action pointer (106/200)
# The total number of frames for videos_8\pointer\video_41.avi is 30
# Processing videos_8\pointer\video_42 (2).avi for action pointer (107/200)
# The total number of frames for videos_8\pointer\video_42 (2).avi is 30
# Processing videos_8\pointer\video_42 (3).avi for action pointer (108/200)
# The total number of frames for videos_8\pointer\video_42 (3).avi is 30
# Processing videos_8\pointer\video_42.avi for action pointer (109/200)
# The total number of frames for videos_8\pointer\video_42.avi is 30
# Processing videos_8\pointer\video_43 (2).avi for action pointer (110/200)
# The total number of frames for videos_8\pointer\video_43 (2).avi is 30
# Processing videos_8\pointer\video_43 (3).avi for action pointer (111/200)
# The total number of frames for videos_8\pointer\video_43 (3).avi is 30
# Processing videos_8\pointer\video_43.avi for action pointer (112/200)
# The total number of frames for videos_8\pointer\video_43.avi is 30
# Processing videos_8\pointer\video_44 (2).avi for action pointer (113/200)
# The total number of frames for videos_8\pointer\video_44 (2).avi is 30
# Processing videos_8\pointer\video_44 (3).avi for action pointer (114/200)
# The total number of frames for videos_8\pointer\video_44 (3).avi is 30
# Processing videos_8\pointer\video_44.avi for action pointer (115/200)
# The total number of frames for videos_8\pointer\video_44.avi is 30
# Processing videos_8\pointer\video_45 (2).avi for action pointer (116/200)
# The total number of frames for videos_8\pointer\video_45 (2).avi is 30
# Processing videos_8\pointer\video_45 (3).avi for action pointer (117/200)
# The total number of frames for videos_8\pointer\video_45 (3).avi is 30
# Processing videos_8\pointer\video_45.avi for action pointer (118/200)
# The total number of frames for videos_8\pointer\video_45.avi is 30
# Processing videos_8\pointer\video_46 (2).avi for action pointer (119/200)
# The total number of frames for videos_8\pointer\video_46 (2).avi is 30
# Processing videos_8\pointer\video_46 (3).avi for action pointer (120/200)
# The total number of frames for videos_8\pointer\video_46 (3).avi is 30
# Processing videos_8\pointer\video_46.avi for action pointer (121/200)
# The total number of frames for videos_8\pointer\video_46.avi is 30
# Processing videos_8\pointer\video_47 (2).avi for action pointer (122/200)
# The total number of frames for videos_8\pointer\video_47 (2).avi is 30
# Processing videos_8\pointer\video_47 (3).avi for action pointer (123/200)
# The total number of frames for videos_8\pointer\video_47 (3).avi is 30
# Processing videos_8\pointer\video_47.avi for action pointer (124/200)
# The total number of frames for videos_8\pointer\video_47.avi is 30
# Processing videos_8\pointer\video_48 (2).avi for action pointer (125/200)
# The total number of frames for videos_8\pointer\video_48 (2).avi is 30
# Processing videos_8\pointer\video_48 (3).avi for action pointer (126/200)
# The total number of frames for videos_8\pointer\video_48 (3).avi is 30
# Processing videos_8\pointer\video_48.avi for action pointer (127/200)
# The total number of frames for videos_8\pointer\video_48.avi is 30
# Processing videos_8\pointer\video_49 (2).avi for action pointer (128/200)
# The total number of frames for videos_8\pointer\video_49 (2).avi is 30
# Processing videos_8\pointer\video_49 (3).avi for action pointer (129/200)
# The total number of frames for videos_8\pointer\video_49 (3).avi is 30
# Processing videos_8\pointer\video_49.avi for action pointer (130/200)
# The total number of frames for videos_8\pointer\video_49.avi is 30
# Processing videos_8\pointer\video_5 (2).avi for action pointer (131/200)
# The total number of frames for videos_8\pointer\video_5 (2).avi is 30
# Processing videos_8\pointer\video_5.avi for action pointer (132/200)
# The total number of frames for videos_8\pointer\video_5.avi is 30
# Processing videos_8\pointer\video_50 (2).avi for action pointer (133/200)
# The total number of frames for videos_8\pointer\video_50 (2).avi is 30
# Processing videos_8\pointer\video_50 (3).avi for action pointer (134/200)
# The total number of frames for videos_8\pointer\video_50 (3).avi is 30
# Processing videos_8\pointer\video_50.avi for action pointer (135/200)
# The total number of frames for videos_8\pointer\video_50.avi is 30
# Processing videos_8\pointer\video_51 (2).avi for action pointer (136/200)
# The total number of frames for videos_8\pointer\video_51 (2).avi is 30
# Processing videos_8\pointer\video_51.avi for action pointer (137/200)
# The total number of frames for videos_8\pointer\video_51.avi is 30
# Processing videos_8\pointer\video_52 (2).avi for action pointer (138/200)
# The total number of frames for videos_8\pointer\video_52 (2).avi is 30
# Processing videos_8\pointer\video_52.avi for action pointer (139/200)
# The total number of frames for videos_8\pointer\video_52.avi is 30
# Processing videos_8\pointer\video_53 (2).avi for action pointer (140/200)
# The total number of frames for videos_8\pointer\video_53 (2).avi is 30
# Processing videos_8\pointer\video_53.avi for action pointer (141/200)
# The total number of frames for videos_8\pointer\video_53.avi is 30
# Processing videos_8\pointer\video_54 (2).avi for action pointer (142/200)
# The total number of frames for videos_8\pointer\video_54 (2).avi is 30
# Processing videos_8\pointer\video_54.avi for action pointer (143/200)
# The total number of frames for videos_8\pointer\video_54.avi is 30
# Processing videos_8\pointer\video_55.avi for action pointer (144/200)
# The total number of frames for videos_8\pointer\video_55.avi is 30
# Processing videos_8\pointer\video_56.avi for action pointer (145/200)
# The total number of frames for videos_8\pointer\video_56.avi is 30
# Processing videos_8\pointer\video_57.avi for action pointer (146/200)
# The total number of frames for videos_8\pointer\video_57.avi is 30
# Processing videos_8\pointer\video_58.avi for action pointer (147/200)
# The total number of frames for videos_8\pointer\video_58.avi is 30
# Processing videos_8\pointer\video_59.avi for action pointer (148/200)
# The total number of frames for videos_8\pointer\video_59.avi is 30
# Processing videos_8\pointer\video_6 (2).avi for action pointer (149/200)
# The total number of frames for videos_8\pointer\video_6 (2).avi is 30
# Processing videos_8\pointer\video_6 (3).avi for action pointer (150/200)
# The total number of frames for videos_8\pointer\video_6 (3).avi is 30
# Processing videos_8\pointer\video_6.avi for action pointer (151/200)
# The total number of frames for videos_8\pointer\video_6.avi is 30
# Processing videos_8\pointer\video_60.avi for action pointer (152/200)
# The total number of frames for videos_8\pointer\video_60.avi is 30
# Processing videos_8\pointer\video_61.avi for action pointer (153/200)
# The total number of frames for videos_8\pointer\video_61.avi is 30
# Processing videos_8\pointer\video_62.avi for action pointer (154/200)
# The total number of frames for videos_8\pointer\video_62.avi is 30
# Processing videos_8\pointer\video_63.avi for action pointer (155/200)
# The total number of frames for videos_8\pointer\video_63.avi is 30
# Processing videos_8\pointer\video_64.avi for action pointer (156/200)
# The total number of frames for videos_8\pointer\video_64.avi is 30
# Processing videos_8\pointer\video_65.avi for action pointer (157/200)
# The total number of frames for videos_8\pointer\video_65.avi is 30
# Processing videos_8\pointer\video_66.avi for action pointer (158/200)
# The total number of frames for videos_8\pointer\video_66.avi is 30
# Processing videos_8\pointer\video_67.avi for action pointer (159/200)
# The total number of frames for videos_8\pointer\video_67.avi is 30
# Processing videos_8\pointer\video_68.avi for action pointer (160/200)
# The total number of frames for videos_8\pointer\video_68.avi is 30
# Processing videos_8\pointer\video_69.avi for action pointer (161/200)
# The total number of frames for videos_8\pointer\video_69.avi is 30
# Processing videos_8\pointer\video_7 (2).avi for action pointer (162/200)
# The total number of frames for videos_8\pointer\video_7 (2).avi is 30
# Processing videos_8\pointer\video_7 (3).avi for action pointer (163/200)
# The total number of frames for videos_8\pointer\video_7 (3).avi is 30
# Processing videos_8\pointer\video_7.avi for action pointer (164/200)
# The total number of frames for videos_8\pointer\video_7.avi is 30
# Processing videos_8\pointer\video_70.avi for action pointer (165/200)
# The total number of frames for videos_8\pointer\video_70.avi is 30
# Processing videos_8\pointer\video_71.avi for action pointer (166/200)
# The total number of frames for videos_8\pointer\video_71.avi is 30
# Processing videos_8\pointer\video_72.avi for action pointer (167/200)
# The total number of frames for videos_8\pointer\video_72.avi is 30
# Processing videos_8\pointer\video_73.avi for action pointer (168/200)
# The total number of frames for videos_8\pointer\video_73.avi is 30
# Processing videos_8\pointer\video_74.avi for action pointer (169/200)
# The total number of frames for videos_8\pointer\video_74.avi is 30
# Processing videos_8\pointer\video_75.avi for action pointer (170/200)
# The total number of frames for videos_8\pointer\video_75.avi is 30
# Processing videos_8\pointer\video_76.avi for action pointer (171/200)
# The total number of frames for videos_8\pointer\video_76.avi is 30
# Processing videos_8\pointer\video_77.avi for action pointer (172/200)
# The total number of frames for videos_8\pointer\video_77.avi is 30
# Processing videos_8\pointer\video_78.avi for action pointer (173/200)
# The total number of frames for videos_8\pointer\video_78.avi is 30
# Processing videos_8\pointer\video_79.avi for action pointer (174/200)
# The total number of frames for videos_8\pointer\video_79.avi is 30
# Processing videos_8\pointer\video_8 (2).avi for action pointer (175/200)
# The total number of frames for videos_8\pointer\video_8 (2).avi is 30
# Processing videos_8\pointer\video_8 (3).avi for action pointer (176/200)
# The total number of frames for videos_8\pointer\video_8 (3).avi is 30
# Processing videos_8\pointer\video_8.avi for action pointer (177/200)
# The total number of frames for videos_8\pointer\video_8.avi is 30
# Processing videos_8\pointer\video_80.avi for action pointer (178/200)
# The total number of frames for videos_8\pointer\video_80.avi is 30
# Processing videos_8\pointer\video_81.avi for action pointer (179/200)
# The total number of frames for videos_8\pointer\video_81.avi is 30
# Processing videos_8\pointer\video_82.avi for action pointer (180/200)
# The total number of frames for videos_8\pointer\video_82.avi is 30
# Processing videos_8\pointer\video_83.avi for action pointer (181/200)
# The total number of frames for videos_8\pointer\video_83.avi is 30
# Processing videos_8\pointer\video_84.avi for action pointer (182/200)
# The total number of frames for videos_8\pointer\video_84.avi is 30
# Processing videos_8\pointer\video_85.avi for action pointer (183/200)
# The total number of frames for videos_8\pointer\video_85.avi is 30
# Processing videos_8\pointer\video_86.avi for action pointer (184/200)
# The total number of frames for videos_8\pointer\video_86.avi is 30
# Processing videos_8\pointer\video_87.avi for action pointer (185/200)
# The total number of frames for videos_8\pointer\video_87.avi is 30
# Processing videos_8\pointer\video_88.avi for action pointer (186/200)
# The total number of frames for videos_8\pointer\video_88.avi is 30
# Processing videos_8\pointer\video_89.avi for action pointer (187/200)
# The total number of frames for videos_8\pointer\video_89.avi is 30
# Processing videos_8\pointer\video_9 (2).avi for action pointer (188/200)
# The total number of frames for videos_8\pointer\video_9 (2).avi is 30
# Processing videos_8\pointer\video_9 (3).avi for action pointer (189/200)
# The total number of frames for videos_8\pointer\video_9 (3).avi is 30
# Processing videos_8\pointer\video_9.avi for action pointer (190/200)
# The total number of frames for videos_8\pointer\video_9.avi is 30
# Processing videos_8\pointer\video_90.avi for action pointer (191/200)
# The total number of frames for videos_8\pointer\video_90.avi is 30
# Processing videos_8\pointer\video_91.avi for action pointer (192/200)
# The total number of frames for videos_8\pointer\video_91.avi is 30
# Processing videos_8\pointer\video_92.avi for action pointer (193/200)
# The total number of frames for videos_8\pointer\video_92.avi is 30
# Processing videos_8\pointer\video_93.avi for action pointer (194/200)
# The total number of frames for videos_8\pointer\video_93.avi is 30
# Processing videos_8\pointer\video_94.avi for action pointer (195/200)
# The total number of frames for videos_8\pointer\video_94.avi is 30
# Processing videos_8\pointer\video_95.avi for action pointer (196/200)
# The total number of frames for videos_8\pointer\video_95.avi is 30
# Processing videos_8\pointer\video_96.avi for action pointer (197/200)
# The total number of frames for videos_8\pointer\video_96.avi is 30
# Processing videos_8\pointer\video_97.avi for action pointer (198/200)
# The total number of frames for videos_8\pointer\video_97.avi is 30
# Processing videos_8\pointer\video_98.avi for action pointer (199/200)
# The total number of frames for videos_8\pointer\video_98.avi is 30
# Processing videos_8\pointer\video_99.avi for action pointer (200/200)
# The total number of frames for videos_8\pointer\video_99.avi is 30
# All videos processed successfully!

# %% [markdown]
# DATA LABELLING

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)} # enumerate just adds index -> [(0, 'zoom_in'), (1, 'zoom_out')]

# %%
# loading the frames - only 200 each
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res) # adding each frame to the window
        sequences.append(window) # adding each the window with the frames to sequence
        labels.append(label_map[action]) # labelling the sequence with the action

# %%
# interpolation of frames with only 0's
import numpy as np
from scipy.interpolate import interp1d

def interpolate_missing_frames(sequence):
    """Interpolates missing frames in a sequence using linear interpolation."""
    sequence = np.array(sequence)  # Convert to NumPy array
    num_frames, num_keypoints = sequence.shape

    # Find indices where frames are missing (all zeros)
    missing_indices = [i for i in range(num_frames) if np.all(sequence[i] == 0)]

    if not missing_indices:  
        return sequence  # No missing frames, return as is

    # Get indices of existing frames
    valid_indices = [i for i in range(num_frames) if i not in missing_indices]
    valid_frames = sequence[valid_indices]

    if len(valid_indices) == 0:
        return sequence  # Avoid error if all frames are missing

    # Apply interpolation
    interp_func = interp1d(valid_indices, valid_frames, axis=0, kind='linear', fill_value="extrapolate")
    interpolated_frames = interp_func(missing_indices)

    # Fill missing frames with interpolated values
    sequence[missing_indices] = interpolated_frames

    return sequence

# Apply interpolation to all sequences
for i in range(len(sequences)):
    if not isinstance(sequences[i], np.ndarray) or sequences[i].size == 0:
        print(f"Skipping empty or invalid sequence {i}")
        continue  # Skip if empty or not a valid NumPy array

    print(f"Processing sequence {i} with shape: {sequences[i].shape}")

    if np.any(np.all(sequences[i] == 0, axis=1)):  # Check for missing frames
        print(f"🔄 Interpolating missing frames in sequence {i}...")
        sequences[i] = interpolate_missing_frames(sequences[i])

# %% [markdown]
# LSTM MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir) # setting the tensorflow directory as log_dir so that all the logs will be stored there

# %%
# CODE FOR MODEL - 1

model = Sequential()

# LSTM layers
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 126)))
model.add(Dropout(0.2)) 
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=False, activation='relu'))

# Fully connected layers
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))

# Output layer
model.add(Dense(actions.shape[0], activation='softmax'))

optimizer = Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# Out:
# C:\Users\FYP TEAM 11\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# TRAINING AND SAVING THE MODEL

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int) # represent the array (labels) in binary format ('zoom_in'->[1,0] 'zoom_out'->[0,1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15) # X -> features , y -> labels

# %%
# Callbacks for early stopping and TensorBoard logging
early_stopping = EarlyStopping(monitor='accuracy', mode='max', patience=10, restore_best_weights=True)
tb_callback = TensorBoard(log_dir="logs", histogram_freq=1)

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=50,  # 50 epochs seems optimal
    validation_data=(X_test, y_test),
    batch_size=32,
    callbacks=[early_stopping, tb_callback]
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - categorical_accuracy: 0.1422 - loss: 1.7912 - val_categorical_accuracy: 0.2556 - val_loss: 1.7303
# Epoch 2/50
#  1/32 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - categorical_accuracy: 0.1875 - loss: 1.8151
# C:\Users\FYP TEAM 11\AppData\Roaming\Python\Python312\site-packages\keras\src\callbacks\early_stopping.py:153: UserWarning: Early stopping conditioned on metric `accuracy` which is not available. Available metrics are: categorical_accuracy,loss,val_categorical_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.2619 - loss: 1.7104 - val_categorical_accuracy: 0.2944 - val_loss: 1.4552
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - categorical_accuracy: 0.3274 - loss: 1.4559 - val_categorical_accuracy: 0.3722 - val_loss: 1.2715
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.3840 - loss: 1.2855 - val_categorical_accuracy: 0.5611 - val_loss: 0.8598
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.4761 - loss: 1.1498 - val_categorical_accuracy: 0.7111 - val_loss: 0.8576
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.5591 - loss: 0.9678 - val_categorical_accuracy: 0.6056 - val_loss: 0.7937
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.6081 - loss: 0.8130 - val_categorical_accuracy: 0.9000 - val_loss: 0.4370
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.7554 - loss: 0.6575 - val_categorical_accuracy: 0.8389 - val_loss: 0.4231
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.8342 - loss: 0.4815 - val_categorical_accuracy: 0.9667 - val_loss: 0.2065
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9117 - loss: 0.3384 - val_categorical_accuracy: 0.9722 - val_loss: 0.0737
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9423 - loss: 0.1985 - val_categorical_accuracy: 0.9944 - val_loss: 0.0268
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.9176 - loss: 0.2785 - val_categorical_accuracy: 0.7333 - val_loss: 0.6342
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.8562 - loss: 0.4282 - val_categorical_accuracy: 0.9611 - val_loss: 0.2311
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9333 - loss: 0.2580 - val_categorical_accuracy: 0.9944 - val_loss: 0.0208
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9556 - loss: 0.1632 - val_categorical_accuracy: 0.9278 - val_loss: 0.2096
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9494 - loss: 0.1984 - val_categorical_accuracy: 0.9833 - val_loss: 0.0665
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - categorical_accuracy: 0.9789 - loss: 0.0968 - val_categorical_accuracy: 0.9667 - val_loss: 0.1314
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9737 - loss: 0.0982 - val_categorical_accuracy: 0.9889 - val_loss: 0.0370
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.8939 - loss: 0.4388 - val_categorical_accuracy: 0.9278 - val_loss: 0.3884
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9376 - loss: 0.2873 - val_categorical_accuracy: 1.0000 - val_loss: 0.0205
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9463 - loss: 0.1911 - val_categorical_accuracy: 0.9889 - val_loss: 0.0471
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.9712 - loss: 0.1359 - val_categorical_accuracy: 0.9944 - val_loss: 0.0205
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9810 - loss: 0.0725 - val_categorical_accuracy: 0.9944 - val_loss: 0.0153
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9546 - loss: 0.1789 - val_categorical_accuracy: 0.9944 - val_loss: 0.0263
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9881 - loss: 0.0696 - val_categorical_accuracy: 0.9944 - val_loss: 0.0087
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - categorical_accuracy: 0.9887 - loss: 0.0528 - val_categorical_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - categorical_accuracy: 0.9960 - loss: 0.0220 - val_categorical_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 28/50
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9953 - loss: 0.0216
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 6
#       3 tb_callback = TensorBoard(log_dir="logs", histogram_freq=1)
#       5 # Train the model
# ----> 6 history = model.fit(
#       7     X_train, y_train,
#       8     epochs=50,  # 50 epochs seems optimal
#       9     validation_data=(X_test, y_test),
#      10     batch_size=32,
#      11     callbacks=[early_stopping, tb_callback]
#      12 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save('final_model_30_frames_200_videos.h5')
model.load_weights('final_model_30_frames_200_videos.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
